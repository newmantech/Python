# %%
# Import libraries
import terality as pd
import numpy as np
import os
# Out:
# You are using version 0.14.14 of the Terality client, but version 0.14.15 is available. Consider upgrading your version to get the latest fixes and features.

# %%
path = r'C:\Users\dbnewman18\Instacart_Basket_Analysis_31_03-2022'

# %%
df_ords_prods = pd.read_parquet(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged/'))
# Out:
# C:\Users\dbnewman18\Instacart_Basket_Analysis_31_03-2022\02 Data\Prepared Data\
# INFO:terality:The result of te.read_parquet was retrieved from cache [docs: https://docs.terality.com/getting-terality/user-guide/caching].

# %%
df=df_ords_prods[:1000000]

# %%
def price_label(row):

  if row['prices'] <= 5:
    return 'Low-range product'
  elif (row['prices'] > 5) and (row['prices'] <= 15):
    return 'Mid-range product'
  elif row['prices'] > 15:
    return 'High range'
  else: return 'Not enough data'

# %%
df['price_range'] = df.apply(price_label, axis=1)

# %%
df['price_range'].value_counts(dropna=False)
# Out:
# Mid-range product    634889
# Low-range product    331220
# Not enough data       24547
# High range             9344
# Name: price_range, dtype: int64

# %%
df['prices'].max()
# Out:
# 24.5

# %%
df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
df.loc[(df['prices'] <= 15) & (df['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
df.loc[df['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
for col in df.columns.tolist():
  weird = (df[[col]].applymap(type) != df[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df[weird]) > 0:
    print (col)
# Out:
# WARNING:terality:Slow operation: DataFrame.applymap was executed on our non-parallelized engine [https://www.terality.com/post/inside-terality-the-non-parallelized-engine]. Please reach out to support@terality.com if you’d like us to prioritise the implementation of the function.
# WARNING:terality:Slow operation: DataFrame.applymap was executed on our non-parallelized engine [https://www.terality.com/post/inside-terality-the-non-parallelized-engine]. Please reach out to support@terality.com if you’d like us to prioritise the implementation of the function.
# WARNING:terality:Slow operation: DataFrame.applymap was executed on our non-parallelized engine [https://www.terality.com/post/inside-terality-the-non-parallelized-engine]. Please reach out to support@terality.com if you’d like us to prioritise the implementation of the function.
# ...

# %%
df['product_name']=df['product_name'].astype('str')

# %%
df['price_range_loc']=df['price_range_loc'].astype('str')

# %%
df['price_range_loc'].value_counts(dropna=False)
# Out:
# Mid-range product     634889
# Low-range product     331220
# None                   24547
# High-range product      9344
# Name: price_range_loc, dtype: int64

# %%
result = []

for value in df_ords_prods["prices"]:
  if value <= 5:
    result.append("Low-range product")
  elif value > 5 and value <=15:
    result.append("Mid-range product")
  elif value >15:
    result.append("High-range product")
  else:
    result.append("Not enough data")
# Out:
# WARNING:terality:Iterating data structures is inefficient, see https://docs.terality.com/getting-terality/user-guide/best-practices-and-anti-patterns for more information.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# C:\Users\DBNEWM~1\AppData\Local\Temp/ipykernel_9724/2488824568.py in <module>
#       4   if value <= 5:
#       5     result.append("Low-range product")
# ----> 6   elif value > 5 and value <=15:
#       7     result.append("Mid-range product")
#       8   elif value >15:
#
# KeyboardInterrupt:

# %%
df_ords_prods.loc[df_ords_prods['prices'] > 15, 'price_range'] = 'High-range product'

# %%
df_ords_prods.loc[(df_ords_prods['prices'] <= 15) & (df_ords_prods['prices'] > 5), 'price_range'] = 'Mid-range product'

# %%
df_ords_prods.loc[df_ords_prods['prices'] <= 5, 'price_range'] = 'Low-range product'

# %%
df_ords_prods.drop(['price_range_loc'], axis=1)
# Out:
#            order_id   user_id  order_number  orders_day_of_week  \
# 0         3139998.0     138.0          28.0                 6.0
# 1         1977647.0     138.0          30.0                 6.0
# 2          389851.0     709.0           2.0                 0.0
# 3          652770.0     764.0           1.0                 3.0
# 4         1813452.0     764.0           3.0                 4.0
# ...             ...       ...           ...                 ...
# 32435065  1788356.0  200215.0           2.0                 0.0
# 32435066  3401313.0  200377.0           1.0                 4.0
# 32435067   809510.0  200873.0           5.0                 3.0
# 32435068  2359893.0  200873.0           9.0                 3.0
# 32435069  2385091.0  205926.0          11.0                 1.0
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# 0                      11.0                     3.0           1
# 1                      17.0                    20.0           1
# ...

# %%
result = []

for value in df_ords_prods["orders_day_of_week"]:
  if value == 0:
    result.append("Busiest day")
  elif value == 4:
    result.append("Least busy")
  else:
    result.append("Regularly busy")
# Out:
# WARNING:terality:Iterating data structures is inefficient, see https://docs.terality.com/getting-terality/user-guide/best-practices-and-anti-patterns for more information.

# %%
df_ords_prods['busiest_day']=result
# Out:
# WARNING:urllib3.connectionpool:Retrying (Retry(total=2, connect=None, read=None, redirect=40, status=None)) after connection broken by 'ProtocolError('Connection aborted.', ConnectionAbortedError(10053, 'An established connection was aborted by the software in your host machine', None, 10053, None))': /v1/compute
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=40, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='api.terality2.com', port=443): Read timed out. (read timeout=3)")': /v1/compute
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=40, status=None)) after connection broken by 'ProtocolError('Connection aborted.', timeout('The write operation timed out'))': /v1/compute
# ---------------------------------------------------------------------------
# SSLWantWriteError                         Traceback (most recent call last)
# ...

# %% [markdown]
# # Task 4.7

# %%
df_ords_prods.loc[df_ords_prods['orders_day_of_week'] == 0, 'busiest_day'] = 'Busiest day'

# %%
df_ords_prods.loc[df_ords_prods['orders_day_of_week'] == 4, 'busiest_day'] = 'Least busy'

# %%
df_ords_prods.loc[(df_ords_prods['orders_day_of_week'] != 0) & (df_ords_prods['orders_day_of_week'] != 4), 'busiest_day'] = 'Regularly busy'

# %%
df_ords_prods.head()
# Out:
#     order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0  3139998.0    138.0          28.0                 6.0               11.0
# 1  1977647.0    138.0          30.0                 6.0               17.0
# 2   389851.0    709.0           2.0                 0.0               21.0
# 3   652770.0    764.0           1.0                 3.0               13.0
# 4  1813452.0    764.0           3.0                 4.0               17.0
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     3.0           1                5.0        0.0
# 1                    20.0           1                1.0        1.0
# 2                     6.0           1               20.0        0.0
# 3                     0.0           1               10.0        0.0
# 4                     9.0           1               11.0        1.0
#
#                  product_name  aisle_id  department_id  prices _merge  \
# ...

# %%
df_ords_prods.drop(['busiest day'], axis=1)
# Out:
#            order_id   user_id  order_number  orders_day_of_week  \
# 0         3139998.0     138.0          28.0                 6.0
# 1         1977647.0     138.0          30.0                 6.0
# 2          389851.0     709.0           2.0                 0.0
# 3          652770.0     764.0           1.0                 3.0
# 4         1813452.0     764.0           3.0                 4.0
# ...             ...       ...           ...                 ...
# 32435065  1788356.0  200215.0           2.0                 0.0
# 32435066  3401313.0  200377.0           1.0                 4.0
# 32435067   809510.0  200873.0           5.0                 3.0
# 32435068  2359893.0  200873.0           9.0                 3.0
# 32435069  2385091.0  205926.0          11.0                 1.0
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# 0                      11.0                     3.0           1
# 1                      17.0                    20.0           1
# ...

# %%
df_ords_prods['orders_day_of_week'].value_counts(dropna=False)
# Out:
# 0.0    6209808
# 1.0    5665951
# 6.0    4500391
# 2.0    4217868
# 5.0    4209603
# 3.0    3844175
# 4.0    3787263
# NaN         11
# Name: orders_day_of_week, dtype: int64

# %%
df_ords_prods.drop(['busiest_day'], axis=1)
# Out:
#            order_id   user_id  order_number  orders_day_of_week  \
# 0         3139998.0     138.0          28.0                 6.0
# 1         1977647.0     138.0          30.0                 6.0
# 2          389851.0     709.0           2.0                 0.0
# 3          652770.0     764.0           1.0                 3.0
# 4         1813452.0     764.0           3.0                 4.0
# ...             ...       ...           ...                 ...
# 32435065  1788356.0  200215.0           2.0                 0.0
# 32435066  3401313.0  200377.0           1.0                 4.0
# 32435067   809510.0  200873.0           5.0                 3.0
# 32435068  2359893.0  200873.0           9.0                 3.0
# 32435069  2385091.0  205926.0          11.0                 1.0
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# 0                      11.0                     3.0           1
# 1                      17.0                    20.0           1
# ...

# %% [markdown]
# ### Creating Busiest/Slowest Column

# %%
df_ords_prods.loc[df_ords_prods['orders_day_of_week'] <= 1, 'busiest_slowest'] = 'Busiest'

# %%
df_ords_prods.loc[(df_ords_prods['orders_day_of_week'] >= 3) & (df_ords_prods['orders_day_of_week'] < 5), 'busiest_slowest'] = 'Slowest'

# %%
df_ords_prods.loc[(df_ords_prods['orders_day_of_week'] != 0) & (df_ords_prods['orders_day_of_week'] != 1) & (df_ords_prods['orders_day_of_week'] != 3) & (df_ords_prods['orders_day_of_week'] != 4), 'busiest_slowest'] = 'Regular'

# %%
df_ords_prods.head()
# Out:
#     order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0  3139998.0    138.0          28.0                 6.0               11.0
# 1  1977647.0    138.0          30.0                 6.0               17.0
# 2   389851.0    709.0           2.0                 0.0               21.0
# 3   652770.0    764.0           1.0                 3.0               13.0
# 4  1813452.0    764.0           3.0                 4.0               17.0
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     3.0           1                5.0        0.0
# 1                    20.0           1                1.0        1.0
# 2                     6.0           1               20.0        0.0
# 3                     0.0           1               10.0        0.0
# 4                     9.0           1               11.0        1.0
#
#                  product_name  aisle_id  department_id  prices _merge  \
# ...

# %%
df_ords_prods.drop(['price_range_loc'], axis=1, inplace=True)

# %%
df_ords_prods.head()
# Out:
#     order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0  3139998.0    138.0          28.0                 6.0               11.0
# 1  1977647.0    138.0          30.0                 6.0               17.0
# 2   389851.0    709.0           2.0                 0.0               21.0
# 3   652770.0    764.0           1.0                 3.0               13.0
# 4  1813452.0    764.0           3.0                 4.0               17.0
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     3.0           1                5.0        0.0
# 1                    20.0           1                1.0        1.0
# 2                     6.0           1               20.0        0.0
# 3                     0.0           1               10.0        0.0
# 4                     9.0           1               11.0        1.0
#
#                  product_name  aisle_id  department_id  prices _merge  \
# ...

# %%
df_ords_prods['busiest_slowest'].value_counts(dropna=False)
# Out:
# Regular    12927873
# Busiest    11875759
# Slowest     7631438
# Name: busiest_slowest, dtype: int64

# %% [markdown]
# The number of orders on "regular" days (Monday, Thurs, Friday) actually outnumbers the number of orders on the two busiest days (Saturday and Sunday).

# %%
df_ords_prods['order_hour_of_day'].value_counts(dropna=False)
# Out:
# 10.0    2764476
# 11.0    2738647
# 14.0    2691598
# 15.0    2664583
# 13.0    2663346
# 12.0    2620898
# 16.0    2537506
# 9.0     2456751
# 17.0    2089510
# 8.0     1719991
# 18.0    1637956
# 19.0    1259416
# 20.0     977049
# 7.0      891951
# 21.0     796379
# 22.0     634743
# 23.0     402621
# 6.0      290796
# 0.0      218951
# 1.0      115787
# 5.0       88064
# 2.0       69435
# 4.0       53284
# 3.0       51321
# NaN          11
# Name: order_hour_of_day, dtype: int64

# %%
df_ords_prods['order_hour_of_day'].describe()
# Out:
# count    3.243506e+07
# mean     1.342498e+01
# std      4.246357e+00
# min      0.000000e+00
# 25%      1.000000e+01
# 50%      1.300000e+01
# 75%      1.600000e+01
# max      2.300000e+01
# Name: order_hour_of_day, dtype: float64

# %%
df_ords_prods.loc[df_ords_prods['order_hour_of_day'] < 7, 'busy_hours'] = 'Fewest orders'

# %%
df_ords_prods.loc[df_ords_prods['order_hour_of_day'] == 23, 'busy_hours'] = 'Fewest orders'

# %%
df_ords_prods.loc[(df_ords_prods['order_hour_of_day'] >= 17) & (df_ords_prods['order_hour_of_day'] <= 22), 'busy_hours'] = 'Average orders'

# %%
df_ords_prods.loc[(df_ords_prods['order_hour_of_day'] >= 7) & (df_ords_prods['order_hour_of_day'] < 9), 'busy_hours'] = 'Average orders'

# %%
df_ords_prods.loc[(df_ords_prods['order_hour_of_day'] >= 9) & (df_ords_prods['order_hour_of_day'] < 17), 'busy_hours'] = 'Most orders'

# %%
df_ords_prods['busy_hours'].value_counts(dropna=False)
# Out:
# Most orders       21137805
# Average orders    10006995
# NaN                 887649
# Fewest orders       402621
# Name: busy_hours, dtype: int64

# %%
df_ords_prods.head()
# Out:
#     order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0  3139998.0    138.0          28.0                 6.0               11.0
# 1  1977647.0    138.0          30.0                 6.0               17.0
# 2   389851.0    709.0           2.0                 0.0               21.0
# 3   652770.0    764.0           1.0                 3.0               13.0
# 4  1813452.0    764.0           3.0                 4.0               17.0
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     3.0           1                5.0        0.0
# 1                    20.0           1                1.0        1.0
# 2                     6.0           1               20.0        0.0
# 3                     0.0           1               10.0        0.0
# 4                     9.0           1               11.0        1.0
#
#                  product_name  aisle_id  department_id  prices _merge  \
# ...

# %%
df_nan=df_ords_prods[df_ords_prods['busy_hours'].isnull()==True]

# %%
df_nan.head()
# Out:
#      order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 17   200390.0   1540.0           4.0                 2.0                0.0
# 19  2920553.0   1540.0           6.0                 1.0                0.0
# 20  2813049.0   1540.0           7.0                 2.0                2.0
# 22  1604797.0   1540.0           9.0                 1.0                3.0
# 32  1424793.0   1540.0          27.0                 1.0                1.0
#
#     days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 17                     7.0           1               10.0        0.0
# 19                    14.0           1                9.0        1.0
# 20                     8.0           1                7.0        1.0
# 22                    28.0           1                6.0        1.0
# 32                     5.0           1                1.0        1.0
#
#                   product_name  aisle_id  department_id  prices _merge  \
# ...

# %%
df_ords_prods.drop(['busiest_hours'], axis=1)
# Out:
#            order_id   user_id  order_number  orders_day_of_week  \
# 0         3139998.0     138.0          28.0                 6.0
# 1         1977647.0     138.0          30.0                 6.0
# 2          389851.0     709.0           2.0                 0.0
# 3          652770.0     764.0           1.0                 3.0
# 4         1813452.0     764.0           3.0                 4.0
# ...             ...       ...           ...                 ...
# 32435065  1788356.0  200215.0           2.0                 0.0
# 32435066  3401313.0  200377.0           1.0                 4.0
# 32435067   809510.0  200873.0           5.0                 3.0
# 32435068  2359893.0  200873.0           9.0                 3.0
# 32435069  2385091.0  205926.0          11.0                 1.0
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# 0                      11.0                     3.0           1
# 1                      17.0                    20.0           1
# ...

# %%
df_nan['order_hour_of_day'].value_counts(dropna=False)
# Out:
# 6.0    290796
# 0.0    218951
# 1.0    115787
# 5.0     88064
# 2.0     69435
# 4.0     53284
# 3.0     51321
# NaN        11
# Name: order_hour_of_day, dtype: int64

# %%
df_ords_prods['busy_hours'] = df_ords_prods['busy_hours'].astype('str')

# %%
df_ords_prods['busy_hours'].value_counts(dropna=False)
# Out:
# Most orders       21137805
# Average orders    10006995
# Fewest orders      1290259
# None                    11
# Name: busy_hours, dtype: int64

# %%
df_ords_prods.to_parquet_folder(os.path.join(path, '02 Data','Prepared Data', 'orders_products_cols_added*.parquet'))
