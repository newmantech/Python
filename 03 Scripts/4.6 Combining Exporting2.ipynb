# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %%
path = r'C:\Users\dbnew\Instacart_Basket_Analysis_31_03-2022'

# %%
df_ords_prods = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_combined.pkl'))

# %%
df_ords_prods.to_parquet(os.path.join(path, '02 Data','Prepared Data', 'df_ords_prods.parquet'))

# %%
import terality as pd

# %%
df_ords_prods.shape
# Out:
# (32434489, 11)

# %%
df_prods = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'products_checked.csv'), index_col=False)
# Out:
# C:\Users\dbnewman18\Instacart_Basket_Analysis_31_03-2022\02 Data\Prepared Data\

# %%
df_ords_prods.head()
# Out:
#    Unnamed: 0  order_id  user_id  order_number  orders_day_of_week  \
# 0           0   2539329        1             1                   2
# 1           0   2539329        1             1                   2
# 2           0   2539329        1             1                   2
# 3           0   2539329        1             1                   2
# 4           0   2539329        1             1                   2
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                       0         196                  1
# 1                  8                       0       14084                  2
# 2                  8                       0       12427                  3
# 3                  8                       0       26088                  4
# 4                  8                       0       26405                  5
#
#    reordered _merge
# 0          0   both
# 1          0   both
# 2          0   both
# ...

# %%
df_ords_prods.drop(['Unnamed: 0', '_merge'], axis=1, inplace=True)

# %%
df_ords_prods.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2539329        1             1                   2                  8
# 2   2539329        1             1                   2                  8
# 3   2539329        1             1                   2                  8
# 4   2539329        1             1                   2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered
# 0                       0         196                  1          0
# 1                       0       14084                  2          0
# 2                       0       12427                  3          0
# 3                       0       26088                  4          0
# 4                       0       26405                  5          0

# %%
df_prods.head()
# Out:
#    Unnamed: 0  product_id                                       product_name  \
# 0           0           1                         Chocolate Sandwich Cookies
# 1           1           2                                   All-Seasons Salt
# 2           2           3               Robust Golden Unsweetened Oolong Tea
# 3           3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4           4           5                          Green Chile Anytime Sauce
#
#    aisle_id  department_id  prices
# 0        61             19     5.8
# 1       104             13     9.3
# 2        94              7     4.5
# 3        38              1    10.5
# 4         5             13     4.3

# %%
df_prods.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
df_ords_prods = pd.read_parquet(os.path.join(path, '02 Data', 'Prepared Data', 'df_ords_prods.parquet'))
# Out:
# C:\Users\dbnewman18\Instacart_Basket_Analysis_31_03-2022\02 Data\Prepared Data\

# %%
df_ords_prods.head()
# Out:
#    Unnamed: 0  order_id  user_id  order_number  orders_day_of_week  \
# 0           0   2539329        1             1                   2
# 1           0   2539329        1             1                   2
# 2           0   2539329        1             1                   2
# 3           0   2539329        1             1                   2
# 4           0   2539329        1             1                   2
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                       0         196                  1
# 1                  8                       0       14084                  2
# 2                  8                       0       12427                  3
# 3                  8                       0       26088                  4
# 4                  8                       0       26405                  5
#
#    reordered _merge
# 0          0   both
# 1          0   both
# 2          0   both
# ...

# %%
df_ords_prods.drop(['Unnamed: 0', '_merge'], axis=1, inplace=True)

# %%
df_ords_prods.head()
# Out:
# INFO:terality:The result of te.dataframe.head was retrieved from cache [docs: https://docs.terality.com/getting-terality/user-guide/caching].
# INFO:terality:The result of te.dataframe._repr_html_ was retrieved from cache [docs: https://docs.terality.com/getting-terality/user-guide/caching].
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2539329        1             1                   2                  8
# 2   2539329        1             1                   2                  8
# 3   2539329        1             1                   2                  8
# 4   2539329        1             1                   2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered
# 0                       0         196                  1          0
# 1                       0       14084                  2          0
# ...

# %%
df_ords_prods_full=df_ords_prods.merge(df_prods, on=['product_id'], how='outer', indicator=True)

# %%
df_ords_prods_full.head()
# Out:
#     order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0  3139998.0    138.0          28.0                 6.0               11.0
# 1  1977647.0    138.0          30.0                 6.0               17.0
# 2   389851.0    709.0           2.0                 0.0               21.0
# 3   652770.0    764.0           1.0                 3.0               13.0
# 4  1813452.0    764.0           3.0                 4.0               17.0
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     3.0           1                5.0        0.0
# 1                    20.0           1                1.0        1.0
# 2                     6.0           1               20.0        0.0
# 3                     0.0           1               10.0        0.0
# 4                     9.0           1               11.0        1.0
#
#                  product_name  aisle_id  department_id  prices _merge
# ...

# %%
df_ords_prods_full['_merge'].value_counts()
# Out:
# both          32404859
# left_only        30200
# right_only          11
# Name: _merge, dtype: int64

# %% [markdown]
# It looks like the majoroty of rows were a complete match, but 30,211 were not. Should I be concerned about this? Did I do anything wrong? Please let me know.

# %%
df_ords_prods_full.to_parquet_folder(os.path.join(path, '02 Data','Prepared Data', 'orders_products_merged_*.parquet'))

# %%
ords_prods_merged=pd.read_parquet(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged/'))

# %%
ords_prods_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32435070 entries, 0 to 32435069
# Data columns (total 14 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   order_id                float64
#  1   user_id                 float64
#  2   order_number            float64
#  3   orders_day_of_week      float64
#  4   order_hour_of_day       float64
#  5   days_since_prior_order  float64
#  6   product_id              int64
#  7   add_to_cart_order       float64
#  8   reordered               float64
#  9   product_name            object
#  10  aisle_id                float64
#  11  department_id           float64
#  12  prices                  float64
#  13  _merge                  category
# dtypes: category(1), float64(11), int64(1), object(1)
# memory usage: 3.4+ GB

# %%
ords_prods_merged.head()
# Out:
#     order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0  3139998.0    138.0          28.0                 6.0               11.0
# 1  1977647.0    138.0          30.0                 6.0               17.0
# 2   389851.0    709.0           2.0                 0.0               21.0
# 3   652770.0    764.0           1.0                 3.0               13.0
# 4  1813452.0    764.0           3.0                 4.0               17.0
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     3.0           1                5.0        0.0
# 1                    20.0           1                1.0        1.0
# 2                     6.0           1               20.0        0.0
# 3                     0.0           1               10.0        0.0
# 4                     9.0           1               11.0        1.0
#
#                  product_name  aisle_id  department_id  prices _merge
# ...
